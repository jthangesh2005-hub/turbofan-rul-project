# %%
# !git clone https://github.com/jthangesh2005-hub/turbofan-rul-project.git
# Out:
# Cloning into 'turbofan-rul-project'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (3/3), done.

# %%
# %cd turbofan-rul-project
# Out:
# /content/turbofan-rul-project

# %%
# !ls
# Out:
# README.md

# %%
# !find /content -name "rul_fd001.ipynb"
